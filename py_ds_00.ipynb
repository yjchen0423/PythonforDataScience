# %%
# %hist
# Out:
# %magic
# %hist

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.plot(np.random.randn(50).cumsum())

# %%
def append_element(some_list, element):
    some_list.append(element)

# %%
data = [1, 2, 3]

# %%
append_element(data, 4)

# %%
data
# Out:
# [1, 2, 3, 4]

# %%
append_element??
# Out:
# Signature: append_element(some_list, element)
# Docstring: <no docstring>
# Source:
# def append_element(some_list, element):
#     some_list.append(element)
# File:      c:\users\yjche\onedrive\python\datascience\pythonfordatascience\<ipython-input-1-be7492b0cb12>
# Type:      function
